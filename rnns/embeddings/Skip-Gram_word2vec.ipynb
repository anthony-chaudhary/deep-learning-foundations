# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
c = Counter(int_words)
l = len(int_words)

f = {word: (i / l) for word, i in c.items()}  # frequency 

p_drop = {word: 1 - np.sqrt( t / f[word] ) for word in c}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

print(len(train_words))
# Out:
# 4628791

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, index, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size + 1)
    
    a = index - R if (index - R) > 0 else 0
    b = index + R
    
    target_words = list( set(words[a : index] + words[index + 1 : b + 1]) )
    
    return  target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    
    inputs = tf.placeholder(tf.int32, [None], name='inputs' )
    
    labels = tf.placeholder(tf.int32, [None, None], name='labels' )

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  #get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros( n_vocab ))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6839 0.0338 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6179 0.0298 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4813 0.0297 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6134 0.0303 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5031 0.0302 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5745 0.0301 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5351 0.0297 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5661 0.0295 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4618 0.0297 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4304 0.0306 sec/batch
# Nearest to from: vector, boathouse, callers, japanese, abba, injuring, supernovae, fertility,
# Nearest to eight: influenced, lemonade, retrospectively, split, yoshino, alkoxide, denethor, starlink,
# Nearest to at: naturals, misfortune, summoning, olof, rectangle, undistinguished, comprehension, glory,
# Nearest to use: rewrites, spring, allmusic, aram, oshkosh, macarthur, magie, vila,
# Nearest to had: bathory, ijtihad, classrooms, landowner, memphis, inari, richmond, hydroxide,
# Nearest to such: tellers, reductionism, cadmium, creative, mandaeans, lan, ods, written,
# Nearest to that: large, proxies, receipts, bigg, injuring, quickdraw, progressive, gentrification,
# Nearest to if: flamel, drift, strewn, disaster, tanya, mistress, relapses, sensations,
# Nearest to engine: bartlett, astrolabe, surveys, schematic, fly, examine, publication, fnl,
# Nearest to joseph: sunga, wilkins, defended, checkpoint, support, triumphant, titanate, afflicted,
# Nearest to universe: synthesize, seasoned, frankenchrist, disagreeable, senatorial, impress, soundtrack, merril,
# Nearest to units: murrah, trustees, stroking, mw, acorn, marseille, osip, exhorting,
# Nearest to consists: dddddd, exponential, banias, tortoiseshell, ornithologist, tin, caymanians, arte,
# Nearest to brother: published, wahid, wide, repertory, ejecta, ath, interstates, sectoral,
# Nearest to hit: bulgars, clampett, schismatic, epitomised, pcc, abjad, humps, rhead,
# Nearest to instance: tms, lingvo, chasm, conservatory, kevlar, bears, vater, cataclysm,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5070 0.0318 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3837 0.0301 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3697 0.0303 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2461 0.0303 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1830 0.0297 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2017 0.0300 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1067 0.0297 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0883 0.0290 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0211 0.0292 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9879 0.0295 sec/batch
# Nearest to from: vector, japanese, callers, supernovae, boathouse, abba, injuring, fertility,
# Nearest to eight: influenced, split, representatives, herself, retrospectively, and, backfire, america,
# Nearest to at: summoning, glory, contrast, naturals, develop, tend, rectangle, near,
# Nearest to use: spring, aram, bequest, how, the, oshkosh, rewrites, supposed,
# Nearest to had: bathory, memphis, developments, landowner, kaiserliche, budding, inari, richmond,
# Nearest to such: written, creative, tellers, lan, diseases, reductionism, gradient, above,
# Nearest to that: large, progressive, receipts, verse, closely, proxies, isn, inpatient,
# Nearest to if: drift, relapses, disaster, flamel, strewn, socially, prepared, m,
# Nearest to engine: surveys, bartlett, astrolabe, fly, publication, schematic, examine, fnl,
# Nearest to joseph: support, triumphant, defended, wilkins, oldest, sunga, wealthy, checkpoint,
# Nearest to universe: seasoned, synthesize, senatorial, soundtrack, frankenchrist, disagreeable, intruders, fallen,
# Nearest to units: trustees, mw, acorn, north, murrah, else, dortmund, television,
# Nearest to consists: exponential, dddddd, arte, tin, banias, ornithologist, romance, colorado,
# Nearest to brother: published, wide, wahid, repertory, interstates, ejecta, protestants, sectoral,
# Nearest to hit: clampett, schismatic, bulgars, programme, abjad, humps, pcc, critical,
# Nearest to instance: return, conservatory, bears, silicon, lingvo, finance, kevlar, libra,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9406 0.0305 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8982 0.0290 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9011 0.0294 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9011 0.0295 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8130 0.0290 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8188 0.0297 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8134 0.0298 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7872 0.0292 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7895 0.0293 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7741 0.0297 sec/batch
# Nearest to from: vector, japanese, supernovae, autonomy, injuring, boathouse, implementing, forestry,
# Nearest to eight: influenced, backfire, italian, representatives, retrospectively, de, concurrent, etudes,
# Nearest to at: summoning, naturals, misfortune, rectangle, glory, comprehension, probabilities, olof,
# Nearest to use: spring, how, aram, alcan, bequest, oshkosh, macarthur, digits,
# Nearest to had: landowner, bathory, richmond, kaiserliche, budding, memphis, developments, rightfully,
# Nearest to such: written, creative, tellers, gradient, ods, distributes, sum, above,
# Nearest to that: large, verse, progressive, receipts, anthem, proxies, closely, injuring,
# Nearest to if: socially, budgets, sensations, drift, strewn, disinherited, disaster, avoiding,
# Nearest to engine: surveys, astrolabe, fly, bartlett, publication, examine, schematic, totals,
# Nearest to joseph: support, defended, wilkins, triumphant, sunga, wealthy, checkpoint, antithesis,
# Nearest to universe: synthesize, senatorial, soundtrack, seasoned, frankenchrist, disagreeable, intruders, revealing,
# Nearest to units: trustees, mw, acorn, marseille, stroking, murrah, foreign, dortmund,
# Nearest to consists: exponential, dddddd, unambiguously, ornithologist, consultant, banias, colorado, arte,
# Nearest to brother: published, wide, repertory, protestants, interstates, wahid, declaration, ejecta,
# Nearest to hit: schismatic, clampett, bulgars, abjad, beer, critical, programme, hydronium,
# Nearest to instance: return, conservatory, cove, lingvo, silicon, bears, finance, leaflet,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7640 0.0309 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7567 0.0295 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6961 0.0291 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7108 0.0291 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7633 0.0292 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6765 0.0298 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7001 0.0298 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7247 0.0290 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7024 0.0298 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6895 0.0297 sec/batch
# Nearest to from: vector, japanese, supernovae, injuring, boathouse, autonomy, implementing, callers,
# Nearest to eight: italian, de, seven, d, etudes, professor, backfire, born,
# Nearest to at: misfortune, naturals, summoning, olof, glory, stranger, framers, nutrition,
# Nearest to use: how, spring, rewrites, pergamon, oshkosh, alcan, allmusic, bequest,
# Nearest to had: richmond, landowner, bathory, rightfully, budding, kaiserliche, vatican, lotteries,
# Nearest to such: creative, written, distributes, ods, tellers, diseases, gradient, cavity,
# Nearest to that: large, verse, proxies, progressive, unless, anthem, receipts, gentrification,
# Nearest to if: sensations, socially, strewn, disinherited, templates, budgets, drift, flamel,
# Nearest to engine: surveys, bartlett, fly, astrolabe, examine, schematic, publication, totals,
# Nearest to joseph: defended, wilkins, wealthy, checkpoint, support, wrestler, triumphant, afflicted,
# Nearest to universe: senatorial, synthesize, seasoned, frankenchrist, soundtrack, intruders, disagreeable, equated,
# Nearest to units: acorn, stroking, mw, marseille, murrah, trustees, foreign, dortmund,
# Nearest to consists: exponential, dddddd, unambiguously, banias, colorado, ornithologist, tin, consultant,
# Nearest to brother: published, repertory, wide, wahid, protestants, interstates, ath, declaration,
# Nearest to hit: bulgars, clampett, schismatic, abjad, ewell, firepower, hydronium, critical,
# Nearest to instance: cove, tms, return, conservatory, lingvo, cataloging, leaflet, shapur,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6657 0.0299 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6749 0.0290 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5980 0.0289 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6446 0.0297 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6311 0.0293 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6335 0.0298 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5922 0.0211 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5553 0.0298 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5204 0.0297 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4984 0.0297 sec/batch
# Nearest to from: vector, japanese, supernovae, boathouse, pune, injuring, implementing, abba,
# Nearest to eight: de, italian, seven, d, born, richard, four, holidays,
# Nearest to at: misfortune, naturals, near, framers, summoning, stranger, probabilities, undistinguished,
# Nearest to use: how, spring, digits, oshkosh, blogs, pergamon, rewrites, alcan,
# Nearest to had: landowner, richmond, bathory, prosecuting, kaiserliche, rightfully, lotteries, memphis,
# Nearest to such: ods, diseases, creative, distributes, above, written, cavity, cadmium,
# Nearest to that: large, objective, verse, unless, proxies, slaughtering, progressive, aspects,
# Nearest to if: templates, strewn, sensations, sweetest, deterministic, organism, example, disinherited,
# Nearest to engine: surveys, bartlett, fly, astrolabe, examine, schematic, centrifugal, publication,
# Nearest to joseph: wrestler, wilkins, checkpoint, wealthy, sunga, york, author, defended,
# Nearest to universe: synthesize, equated, senatorial, seasoned, intruders, we, soundtrack, disagreeable,
# Nearest to units: acorn, marseille, excitation, stroking, murrah, dortmund, mw, punks,
# Nearest to consists: dddddd, exponential, unambiguously, banias, colorado, tin, tortoiseshell, millimetres,
# Nearest to brother: published, ath, wahid, protestants, repertory, declaration, interstates, ejecta,
# Nearest to hit: clampett, bulgars, rhead, epitomised, schismatic, ewell, abjad, simpsons,
# Nearest to instance: cove, tms, shapur, cataloging, variations, return, ddt, procured,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5041 0.0307 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5156 0.0302 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4822 0.0293 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5142 0.0296 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5046 0.0296 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4493 0.0295 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4541 0.0294 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3975 0.0293 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4257 0.0294 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4352 0.0296 sec/batch
# Nearest to from: boathouse, vector, thoroughfares, supernovae, eradicated, implementing, japanese, injuring,
# Nearest to eight: seven, italian, de, d, america, born, carson, holidays,
# Nearest to at: misfortune, naturals, framers, summoning, near, strangle, deteriorates, undistinguished,
# Nearest to use: how, digits, spring, rewrites, oshkosh, blogs, forensics, initial,
# Nearest to had: landowner, richmond, bathory, prosecuting, lotteries, rightfully, ijtihad, vatican,
# Nearest to such: ods, distributes, diseases, depends, creative, consonance, tellers, quadratic,
# Nearest to that: unless, verse, proxies, objective, large, slaughtering, hidden, inpatient,
# Nearest to if: templates, y, deterministic, sensations, organism, intent, ways, example,
# Nearest to engine: surveys, fly, bartlett, centrifugal, astrolabe, schematic, examine, totals,
# Nearest to joseph: checkpoint, wealthy, wilkins, sunga, defended, triumphant, wrestler, poems,
# Nearest to universe: equated, synthesize, we, intruders, constabulary, seasoned, disagreeable, conceits,
# Nearest to units: acorn, excitation, stroking, dortmund, marseille, positives, somber, learned,
# Nearest to consists: dddddd, exponential, colorado, banias, unambiguously, millimetres, tin, induces,
# Nearest to brother: published, protestants, ath, declaration, repertory, wahid, franciscan, edwin,
# Nearest to hit: clampett, epitomised, ewell, simpsons, bulgars, abjad, humps, rhead,
# Nearest to instance: tms, cove, shapur, ddt, variations, not, cataloging, seigneurial,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4377 0.0302 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4315 0.0291 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4280 0.0292 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4044 0.0297 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4322 0.0346 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4280 0.0302 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3712 0.0298 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3750 0.0298 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4124 0.0294 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3793 0.0301 sec/batch
# Nearest to from: vector, boathouse, thoroughfares, supernovae, japanese, eradicated, masque, turning,
# Nearest to eight: seven, de, italian, born, four, floats, carson, backfire,
# Nearest to at: naturals, misfortune, summoning, protoscience, gates, deteriorates, framers, stranger,
# Nearest to use: how, spring, digits, oshkosh, rewrites, forensics, initial, optimized,
# Nearest to had: landowner, richmond, prosecuting, bathory, lotteries, budding, vatican, kaiserliche,
# Nearest to such: ods, quadratic, consonance, distributes, creative, tellers, depends, sonar,
# Nearest to that: proxies, verse, unless, hidden, objective, large, mathilde, will,
# Nearest to if: y, templates, intent, sensations, organism, strewn, ways, invincible,
# Nearest to engine: fly, surveys, centrifugal, bartlett, diving, schematic, examine, astrolabe,
# Nearest to joseph: checkpoint, wealthy, wilkins, sunga, wrestler, presumptive, poems, victor,
# Nearest to universe: equated, we, synthesize, disagreeable, constabulary, intruders, seasoned, conceits,
# Nearest to units: acorn, excitation, positives, reactor, stroking, dortmund, waas, mw,
# Nearest to consists: dddddd, exponential, colorado, banias, unambiguously, tortoiseshell, coronal, flirted,
# Nearest to brother: published, repertory, ath, declaration, protestants, franciscan, gianni, wahid,
# Nearest to hit: clampett, epitomised, simpsons, winning, abjad, ewell, deuteronomic, tagline,
# Nearest to instance: tms, variations, cove, not, cataloging, ddt, seigneurial, geometric,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3752 0.0314 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3900 0.0302 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3556 0.0300 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3403 0.0297 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4095 0.0296 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3940 0.0299 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3675 0.0304 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3759 0.0297 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3473 0.0296 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3286 0.0295 sec/batch
# Nearest to from: vector, eradicated, boathouse, pune, thoroughfares, supernovae, masque, khobar,
# Nearest to eight: seven, four, zero, six, de, floats, est, backfire,
# Nearest to at: naturals, protoscience, misfortune, gates, framers, hotels, probabilities, hecatonchires,
# Nearest to use: how, spring, oshkosh, rewrites, digits, forensics, initial, alcan,
# Nearest to had: landowner, solway, bathory, employer, richmond, led, lotteries, kaiserliche,
# Nearest to such: distributes, quadratic, ods, creative, consonance, sonar, straddle, globally,
# Nearest to that: proxies, hidden, unless, objective, large, mathilde, will, progressive,
# Nearest to if: intent, y, action, sensations, strewn, templates, organism, browns,
# Nearest to engine: fly, centrifugal, surveys, bartlett, diving, astrolabe, fat, adaptations,
# Nearest to joseph: wealthy, checkpoint, sunga, triumphant, wilkins, edmond, resurface, reunified,
# Nearest to universe: equated, we, synthesize, disagreeable, identities, quantum, intruders, constabulary,
# Nearest to units: acorn, positives, stroking, reactor, excitation, waas, fastest, mw,
# Nearest to consists: dddddd, exponential, colorado, banias, unambiguously, tortoiseshell, unification, coronal,
# Nearest to brother: repertory, published, ath, gianni, wahid, declaration, protestants, franciscan,
# Nearest to hit: clampett, epitomised, simpsons, winning, ewell, deuteronomic, rhead, mvp,
# Nearest to instance: tms, variations, geometric, cataloging, cove, not, seigneurial, exemplar,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3307 0.0310 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3118 0.0301 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3870 0.0299 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3968 0.0310 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3918 0.0308 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3104 0.0300 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3034 0.0308 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3230 0.0306 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2242 0.0301 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2961 0.0300 sec/batch
# Nearest to from: pune, eradicated, masque, boathouse, khobar, thoroughfares, vector, turning,
# Nearest to eight: seven, six, four, d, zero, de, nine, statesman,
# Nearest to at: naturals, misfortune, gates, protoscience, laurent, undistinguished, hotels, hecatonchires,
# Nearest to use: how, oshkosh, digits, loudspeaker, spring, blogs, rewrites, forensics,
# Nearest to had: landowner, solway, led, bathory, employer, overshadowing, comrades, ijtihad,
# Nearest to such: quadratic, distributes, ods, creative, plucked, consonance, globally, mandaeans,
# Nearest to that: proxies, unless, hidden, will, objective, mathilde, verse, progressive,
# Nearest to if: y, intent, sensations, action, strewn, templates, rcn, subexpression,
# Nearest to engine: fly, centrifugal, diving, surveys, bartlett, fat, totals, astrolabe,
# Nearest to joseph: wealthy, checkpoint, kampf, edmond, sunga, triumphant, electronica, honorary,
# Nearest to universe: equated, we, synthesize, disagreeable, conceits, quantum, intruders, identities,
# Nearest to units: acorn, positives, stroking, reactor, excitation, foreign, waas, mw,
# Nearest to consists: dddddd, colorado, banias, exponential, tortoiseshell, unambiguously, unification, incessant,
# Nearest to brother: ath, repertory, gianni, wahid, declaration, franciscan, published, ravaged,
# Nearest to hit: clampett, epitomised, simpsons, rhead, winning, deuteronomic, tagline, debut,
# Nearest to instance: tms, geometric, variations, cataloging, exemplar, seigneurial, not, chasm,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2941 0.0309 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2901 0.0314 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3531 0.0140 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2383 0.0299 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2158 0.0299 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2170 0.0302 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2152 0.0299 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2069 0.0297 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2226 0.0295 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1691 0.0297 sec/batch
# Nearest to from: pune, eradicated, argentina, thoroughfares, masque, khobar, boathouse, harriers,
# Nearest to eight: seven, six, four, est, d, zero, de, hdi,
# Nearest to at: gates, hotels, naturals, misfortune, protoscience, strangle, hecatonchires, laurent,
# Nearest to use: how, oshkosh, spring, loudspeaker, slowdown, optimized, maffei, digits,
# Nearest to had: solway, landowner, led, comrades, bathory, pelagius, employer, lotteries,
# Nearest to such: creative, ods, plucked, distributes, quadratic, consonance, mandaeans, sonar,
# Nearest to that: proxies, unless, hidden, will, angle, progressive, objective, credence,
# Nearest to if: intent, y, action, subexpression, sensations, strewn, rcn, invincible,
# Nearest to engine: fly, centrifugal, diving, engines, surveys, bartlett, astrolabe, totals,
# Nearest to joseph: wealthy, edmond, sunga, presumptive, kampf, checkpoint, triumphant, mandel,
# Nearest to universe: equated, disagreeable, intruders, we, conceits, quantum, synthesize, milgram,
# Nearest to units: acorn, positives, stroking, front, reactor, overhanging, foreign, iktinos,
# Nearest to consists: colorado, dddddd, tortoiseshell, exponential, coronal, banias, unambiguously, unification,
# Nearest to brother: wahid, ath, declaration, repertory, gianni, protestants, franciscan, unanimously,
# Nearest to hit: epitomised, clampett, winning, simpsons, rhead, ellipsoid, firepower, debut,
# Nearest to instance: tms, cataloging, chasm, exemplar, geometric, seigneurial, shapur, variations,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2290 0.0305 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2014 0.0298 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2484 0.0294 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1238 0.0305 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1679 0.0305 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1465 0.0298 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1628 0.0294 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1689 0.0297 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2287 0.0295 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1624 0.0297 sec/batch
# Nearest to from: vector, boathouse, pune, eradicated, khobar, masque, thoroughfares, japanese,
# Nearest to eight: seven, six, four, est, zero, hdi, five, lakeside,
# Nearest to at: gates, misfortune, protoscience, probabilities, strangle, naturals, unforgettable, liberalised,
# Nearest to use: how, loudspeaker, oshkosh, rewrites, optimized, maffei, spring, slowdown,
# Nearest to had: landowner, solway, led, ijtihad, overshadowing, comrades, employer, lotteries,
# Nearest to such: plucked, creative, ods, distributes, quadratic, globally, sonar, consonance,
# Nearest to that: hidden, will, unless, mathilde, proxies, angle, credence, isn,
# Nearest to if: y, intent, subexpression, undefined, sensations, action, fact, suppose,
# Nearest to engine: fly, centrifugal, engines, diving, totals, alus, astrolabe, bartlett,
# Nearest to joseph: wealthy, sunga, resurface, antithesis, presumptive, kampf, triumphant, edmond,
# Nearest to universe: equated, quantum, synthesize, disagreeable, intruders, posits, conceits, milgram,
# Nearest to units: acorn, positives, reactor, iktinos, waas, front, overhanging, stroking,
# Nearest to consists: colorado, tortoiseshell, coronal, dddddd, exponential, banias, unambiguously, induces,
# Nearest to brother: wahid, repertory, ath, gianni, ravaged, phoenix, declaration, unanimously,
# Nearest to hit: epitomised, clampett, winning, simpsons, rhead, firepower, ellipsoid, debut,
# Nearest to instance: tms, chasm, cataloging, geometric, zeros, seigneurial, exemplar, variations,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1782 0.0310 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1884 0.0293 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1669 0.0295 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1622 0.0293 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1679 0.0294 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1886 0.0293 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1940 0.0299 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1757 0.0294 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1246 0.0294 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1766 0.0290 sec/batch
# Nearest to from: pune, vector, khobar, masque, eradicated, boathouse, argentina, megaliths,
# Nearest to eight: seven, six, four, five, est, nine, zero, two,
# Nearest to at: gates, probabilities, naturals, strangle, doubting, protoscience, astin, misfortune,
# Nearest to use: loudspeaker, oshkosh, how, spring, maffei, optimized, rewrites, eighties,
# Nearest to had: led, solway, landowner, comrades, overshadowing, ijtihad, flintlock, employer,
# Nearest to such: plucked, distributes, creative, ods, straddle, tellers, taiwanese, consonance,
# Nearest to that: hidden, proxies, mathilde, credence, will, ignorance, conserved, unless,
# Nearest to if: y, subexpression, action, intent, invincible, suppose, browns, sensations,
# Nearest to engine: fly, centrifugal, engines, astrolabe, bartlett, totals, alus, examine,
# Nearest to joseph: sunga, wealthy, edmond, presumptive, kampf, resurface, checkpoint, hanlon,
# Nearest to universe: equated, quantum, disagreeable, posits, synthesize, intruders, cosmology, milgram,
# Nearest to units: acorn, positives, waas, iktinos, stroking, reactor, mw, foreign,
# Nearest to consists: colorado, tortoiseshell, exponential, coronal, dddddd, banias, unification, unambiguously,
# Nearest to brother: repertory, wahid, ravaged, ath, gianni, phoenix, declaration, protestants,
# Nearest to hit: epitomised, clampett, rhead, simpsons, firepower, winning, ellipsoid, distracted,
# Nearest to instance: tms, cataloging, chasm, exemplar, seigneurial, geometric, vertigo, apprehend,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2077 0.0309 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1837 0.0294 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1927 0.0300 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1596 0.0297 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1586 0.0300 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1560 0.0300 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1969 0.0297 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1265 0.0299 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1898 0.0305 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2154 0.0293 sec/batch
# Nearest to from: pune, khobar, masque, argentina, olaf, eradicated, boathouse, teutonic,
# Nearest to eight: seven, six, four, five, zero, three, two, nine,
# Nearest to at: gates, enrollment, laurent, he, unforgettable, near, naturals, misfortune,
# Nearest to use: oshkosh, loudspeaker, maffei, spring, slowdown, eighties, rewrites, optimized,
# Nearest to had: solway, led, landowner, employer, comrades, overshadowing, pelagius, resisted,
# Nearest to such: plucked, creative, distributes, straddle, ods, heroines, positivists, mandaeans,
# Nearest to that: proxies, mathilde, hidden, credence, unless, will, obstinate, verse,
# Nearest to if: y, intent, subexpression, action, invincible, suppose, browns, sparks,
# Nearest to engine: fly, centrifugal, engines, astrolabe, bartlett, alus, powerplant, diving,
# Nearest to joseph: wealthy, sunga, resurface, kampf, edmond, giancana, checkpoint, presumptive,
# Nearest to universe: equated, disagreeable, quantum, intruders, cosmology, merril, posits, cosmological,
# Nearest to units: acorn, positives, foreign, waas, stroking, reactor, overhanging, parte,
# Nearest to consists: colorado, tortoiseshell, coronal, exponential, banias, is, unification, dddddd,
# Nearest to brother: repertory, ravaged, phoenix, wahid, gianni, ath, published, declaration,
# Nearest to hit: epitomised, clampett, rhead, simpsons, firepower, ewell, mvp, distracted,
# Nearest to instance: tms, cataloging, chasm, exemplar, seigneurial, lingvo, geometric, apprehend,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2178 0.0307 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1304 0.0299 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1177 0.0295 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1357 0.0297 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0343 0.0297 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1289 0.0300 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1338 0.0297 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1405 0.0305 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1719 0.0051 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1211 0.0294 sec/batch
# Nearest to from: pune, khobar, masque, vector, boathouse, turning, argentina, eradicated,
# Nearest to eight: seven, six, four, zero, five, est, three, two,
# Nearest to at: probabilities, gates, enrollment, misfortune, near, laurent, naturals, strangle,
# Nearest to use: loudspeaker, oshkosh, maffei, how, slowdown, optimized, initial, rewrites,
# Nearest to had: solway, employer, led, cavallo, landowner, comrades, overshadowing, flintlock,
# Nearest to such: creative, distributes, plucked, globally, straddle, consonance, tellers, scrambling,
# Nearest to that: unless, proxies, hidden, will, credence, mathilde, objective, fine,
# Nearest to if: y, subexpression, intent, suppose, action, invincible, sparks, fact,
# Nearest to engine: fly, centrifugal, engines, powerplant, alus, astrolabe, bartlett, lner,
# Nearest to joseph: wealthy, sunga, edmond, kampf, resurface, giancana, presumptive, sole,
# Nearest to universe: equated, disagreeable, cosmology, quantum, intruders, posits, merril, exalted,
# Nearest to units: acorn, positives, overhanging, mw, foreign, waas, parte, iktinos,
# Nearest to consists: tortoiseshell, colorado, coronal, exponential, dddddd, is, incessant, unification,
# Nearest to brother: repertory, ravaged, phoenix, wahid, gianni, declaration, ath, deorum,
# Nearest to hit: epitomised, rhead, clampett, ewell, simpsons, mvp, firepower, distracted,
# Nearest to instance: tms, cataloging, geometric, exemplar, chasm, apprehend, seigneurial, not,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0891 0.0305 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0967 0.0302 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1076 0.0294 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0566 0.0298 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0670 0.0302 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0690 0.0293 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1084 0.0302 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0781 0.0301 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1104 0.0294 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0463 0.0296 sec/batch
# Nearest to from: pune, argentina, khobar, vector, turning, eradicated, megaliths, diligently,
# Nearest to eight: seven, six, four, est, zero, five, hdi, three,
# Nearest to at: enrollment, gates, probabilities, misfortune, near, unforgettable, hotels, naturals,
# Nearest to use: loudspeaker, slowdown, oshkosh, maffei, initial, rewrites, optimized, judicious,
# Nearest to had: solway, bathory, overshadowing, comrades, led, lotteries, was, returned,
# Nearest to such: creative, distributes, plucked, straddle, tellers, taiwanese, consonance, ethical,
# Nearest to that: hidden, proxies, unless, angle, obstinate, credence, mathilde, fine,
# Nearest to if: y, subexpression, suppose, intent, invincible, undefined, fact, is,
# Nearest to engine: fly, engines, centrifugal, powerplant, bartlett, astrolabe, alus, examine,
# Nearest to joseph: wealthy, sunga, resurface, kampf, giancana, edmond, checkpoint, antithesis,
# Nearest to universe: equated, quantum, cosmological, cosmology, galaxies, disagreeable, arxiv, intruders,
# Nearest to units: acorn, positives, foreign, mw, overhanging, waas, parte, blimp,
# Nearest to consists: colorado, tortoiseshell, coronal, exponential, is, dddddd, incessant, unification,
# Nearest to brother: ravaged, repertory, phoenix, wahid, gianni, deorum, declaration, ath,
# Nearest to hit: epitomised, rhead, clampett, winning, mvp, ewell, simpsons, balls,
# Nearest to instance: tms, cataloging, lingvo, geometric, apprehend, seigneurial, chasm, not,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0486 0.0306 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0163 0.0299 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0411 0.0297 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0442 0.0295 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0573 0.0301 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0456 0.0301 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0661 0.0300 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1145 0.0299 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0511 0.0303 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0244 0.0297 sec/batch
# Nearest to from: vector, argentina, that, pune, masque, boathouse, khobar, diligently,
# Nearest to eight: seven, six, four, est, five, two, zero, three,
# Nearest to at: gates, enrollment, probabilities, naturals, misfortune, strangle, unforgettable, doubting,
# Nearest to use: initial, optimized, judicious, loudspeaker, disabled, scholarly, eighties, maffei,
# Nearest to had: solway, overshadowing, returned, flintlock, camulodunum, comrades, second, ijtihad,
# Nearest to such: distributes, creative, plucked, globally, scrambling, arithmetical, tellers, taiwanese,
# Nearest to that: proxies, hidden, unless, conserved, credence, from, mathilde, objective,
# Nearest to if: y, subexpression, fact, suppose, removing, is, intent, uncountably,
# Nearest to engine: fly, engines, centrifugal, powerplant, alus, astrolabe, schematic, bartlett,
# Nearest to joseph: wealthy, sunga, resurface, giancana, kampf, checkpoint, edmond, presumptive,
# Nearest to universe: equated, quantum, cosmological, cosmology, galaxies, arxiv, intruders, merril,
# Nearest to units: acorn, positives, foreign, blimp, mw, reactor, overhanging, waas,
# Nearest to consists: tortoiseshell, coronal, colorado, is, exponential, dddddd, arthropod, banias,
# Nearest to brother: ravaged, repertory, phoenix, wahid, gianni, declaration, ath, leander,
# Nearest to hit: epitomised, clampett, rhead, ewell, mvp, winning, hits, foul,
# Nearest to instance: tms, not, saving, geometric, cataloging, seigneurial, exemplar, chasm,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0382 0.0307 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1008 0.0298 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0862 0.0295 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0602 0.0301 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0832 0.0301 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0451 0.0296 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1016 0.0299 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0455 0.0296 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0869 0.0306 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0677 0.0303 sec/batch
# Nearest to from: vector, pune, khobar, the, argentina, that, masque, one,
# Nearest to eight: seven, six, four, five, zero, three, two, est,
# Nearest to at: enrollment, near, gates, probabilities, he, misfortune, laurent, ecole,
# Nearest to use: optimized, judicious, maffei, loudspeaker, disabled, eighties, initial, oshkosh,
# Nearest to had: was, overshadowing, solway, led, he, returned, flintlock, camulodunum,
# Nearest to such: creative, plucked, distributes, taiwanese, straddle, globally, scrambling, consonance,
# Nearest to that: hidden, proxies, mathilde, unless, credence, quaid, from, persons,
# Nearest to if: y, subexpression, action, intent, will, suppose, removing, uncountably,
# Nearest to engine: fly, engines, centrifugal, powerplant, bartlett, alus, astrolabe, examine,
# Nearest to joseph: wealthy, sunga, resurface, kampf, giancana, edmond, checkpoint, domestication,
# Nearest to universe: quantum, cosmology, equated, cosmological, galaxies, arxiv, merril, intruders,
# Nearest to units: acorn, positives, blimp, mw, foreign, overhanging, waas, stroking,
# Nearest to consists: tortoiseshell, colorado, coronal, exponential, arthropod, banias, is, incessant,
# Nearest to brother: ravaged, phoenix, wahid, declaration, modena, repertory, younger, deorum,
# Nearest to hit: epitomised, clampett, rhead, ewell, mvp, scoreboard, distracted, winning,
# Nearest to instance: tms, saving, seigneurial, exemplar, geometric, lingvo, caliphate, apprehend,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0389 0.0307 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9908 0.0293 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0464 0.0294 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0777 0.0297 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0637 0.0300 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1307 0.0299 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1440 0.0300 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0429 0.0300 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0286 0.0292 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0600 0.0298 sec/batch
# Nearest to from: pune, argentina, the, vector, masque, is, khobar, osage,
# Nearest to eight: seven, six, four, zero, two, five, est, three,
# Nearest to at: enrollment, gates, probabilities, ecole, hospital, misfortune, laurent, naturals,
# Nearest to use: judicious, optimized, loudspeaker, scholarly, initial, maffei, eighties, oshkosh,
# Nearest to had: overshadowing, was, he, solway, flintlock, led, resisted, returned,
# Nearest to such: creative, distributes, plucked, taiwanese, scrambling, straddle, globally, consonance,
# Nearest to that: hidden, proxies, unless, mathilde, whatever, isn, it, quaid,
# Nearest to if: subexpression, y, uncountably, suppose, will, removing, action, equals,
# Nearest to engine: engines, fly, centrifugal, alus, powerplant, bartlett, astrolabe, hyundai,
# Nearest to joseph: wealthy, sunga, resurface, kampf, giancana, edmond, mandel, sole,
# Nearest to universe: cosmology, equated, quantum, cosmological, merril, intruders, arxiv, galaxies,
# Nearest to units: acorn, foreign, mw, blimp, positives, overhanging, waas, parte,
# Nearest to consists: tortoiseshell, coronal, colorado, is, exponential, arthropod, banias, suomenlinna,
# Nearest to brother: ravaged, phoenix, declaration, wahid, repertory, modena, leander, furnished,
# Nearest to hit: epitomised, clampett, rhead, ewell, mvp, hitters, scoreboard, distracted,
# Nearest to instance: saving, tms, geometric, exemplar, seigneurial, satirical, not, unintelligible,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9741 0.0313 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9984 0.0292 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0293 0.0296 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0210 0.0297 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0807 0.0300 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0626 0.0268 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0313 0.0304 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0169 0.0304 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0350 0.0299 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9923 0.0299 sec/batch
# Nearest to from: the, pune, is, zither, argentina, osage, vector, masque,
# Nearest to eight: seven, six, four, five, nine, zero, two, three,
# Nearest to at: enrollment, gates, near, probabilities, misfortune, hotels, hospital, highbury,
# Nearest to use: optimized, judicious, oshkosh, loudspeaker, slowdown, disabled, scholarly, eighties,
# Nearest to had: was, he, overshadowing, scouring, farnham, flintlock, returned, solway,
# Nearest to such: creative, taiwanese, plucked, chelating, distributes, positivists, consonance, mandaeans,
# Nearest to that: hidden, proxies, unless, happens, the, isn, conserved, quaid,
# Nearest to if: subexpression, y, removing, uncountably, action, raised, myelinolysis, will,
# Nearest to engine: engines, fly, centrifugal, powerplant, alus, bartlett, examine, astrolabe,
# Nearest to joseph: wealthy, sunga, resurface, giancana, kampf, edmond, mandel, wilkins,
# Nearest to universe: cosmology, quantum, cosmological, equated, merril, intruders, galaxies, restores,
# Nearest to units: acorn, mw, positives, foreign, waas, blimp, overhanging, stroking,
# Nearest to consists: tortoiseshell, coronal, colorado, is, banias, arthropod, suomenlinna, microcode,
# Nearest to brother: ravaged, declaration, phoenix, wahid, paphos, modena, ath, stunningly,
# Nearest to hit: epitomised, rhead, clampett, ewell, voortrekkers, mvp, winning, hitters,
# Nearest to instance: saving, tms, seigneurial, exemplar, satirical, caliphate, geometric, return,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9904 0.0306 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9422 0.0295 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0083 0.0298 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0095 0.0296 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0228 0.0299 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0254 0.0295 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9182 0.0295 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9557 0.0305 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9345 0.0300 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9655 0.0297 sec/batch
# Nearest to from: is, vector, argentina, the, zither, romani, one, pune,
# Nearest to eight: seven, six, four, zero, two, five, three, nine,
# Nearest to at: enrollment, gates, highbury, probabilities, misfortune, near, unforgettable, ecole,
# Nearest to use: judicious, optimized, scholarly, loudspeaker, slowdown, disabled, interleaved, initial,
# Nearest to had: was, overshadowing, he, second, scouring, returned, farnham, meran,
# Nearest to such: taiwanese, chelating, distributes, creative, collor, as, plucked, assortment,
# Nearest to that: hidden, unless, the, conserved, it, happens, abstracts, proxies,
# Nearest to if: subexpression, y, uncountably, removing, will, surjective, is, suppose,
# Nearest to engine: engines, fly, centrifugal, powerplant, alus, bartlett, hyundai, examine,
# Nearest to joseph: wealthy, resurface, sunga, giancana, kampf, edmond, farming, conformist,
# Nearest to universe: cosmology, cosmological, quantum, equated, galaxies, proposed, merril, restores,
# Nearest to units: acorn, foreign, blimp, mw, positives, waas, calibre, stroking,
# Nearest to consists: tortoiseshell, coronal, is, colorado, maille, exponential, arthropod, microcode,
# Nearest to brother: ravaged, phoenix, starlight, declaration, paphos, furnished, stunningly, repertory,
# Nearest to hit: epitomised, rhead, clampett, ewell, hitters, foul, winning, hits,
# Nearest to instance: saving, tms, seigneurial, satirical, apprehend, return, not, caliphate,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0018 0.0313 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0051 0.0297 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9695 0.0293 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0190 0.0289 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0370 0.0298 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9632 0.0299 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9892 0.0294 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0188 0.0302 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9997 0.0298 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9957 0.0292 sec/batch
# Nearest to from: the, one, is, argentina, vector, romani, abba, zither,
# Nearest to eight: seven, six, four, nine, five, two, three, one,
# Nearest to at: probabilities, enrollment, gates, hospital, highbury, conferences, naturals, doubting,
# Nearest to use: scholarly, disabled, judicious, eighties, loudspeaker, lightfoot, optimized, initial,
# Nearest to had: was, he, overshadowing, farnham, flintlock, later, meran, bandmates,
# Nearest to such: creative, taiwanese, as, plucked, chelating, scrambling, globally, analogously,
# Nearest to that: hidden, the, unless, conserved, proxies, whatever, isn, approve,
# Nearest to if: subexpression, y, removing, uncountably, action, will, equals, raised,
# Nearest to engine: engines, centrifugal, fly, powerplant, alus, hyundai, astrolabe, bartlett,
# Nearest to joseph: wealthy, sunga, resurface, giancana, edmond, kampf, mandel, smith,
# Nearest to universe: cosmology, cosmological, galaxies, quantum, merril, equated, proposed, arxiv,
# Nearest to units: mw, foreign, waas, blimp, stroking, acorn, positives, pb,
# Nearest to consists: tortoiseshell, coronal, is, colorado, maille, exponential, algol, matrices,
# Nearest to brother: ravaged, phoenix, paphos, declaration, younger, stunningly, wahid, flavia,
# Nearest to hit: epitomised, rhead, clampett, hits, hitters, ewell, distracted, authorising,
# Nearest to instance: saving, tms, satirical, apprehend, geometric, seigneurial, horns, vertigo,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9910 0.0314 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9940 0.0295 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9978 0.0296 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0029 0.0300 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0057 0.0298 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9828 0.0300 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9935 0.0294 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9639 0.0297 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9791 0.0296 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0253 0.0300 sec/batch
# Nearest to from: the, is, one, argentina, romani, vector, osage, pune,
# Nearest to eight: seven, six, four, two, five, zero, nine, three,
# Nearest to at: enrollment, gates, near, probabilities, ecole, hospital, highbury, jerusalem,
# Nearest to use: eighties, optimized, disabled, judicious, scholarly, slowdown, loudspeaker, terrorists,
# Nearest to had: was, he, overshadowing, later, abandoned, safavid, flintlock, second,
# Nearest to such: taiwanese, as, creative, collor, chelating, globally, distributes, scrambling,
# Nearest to that: hidden, proxies, it, conserved, unless, abstracts, the, quaid,
# Nearest to if: subexpression, y, removing, will, uncountably, raised, action, discretion,
# Nearest to engine: engines, centrifugal, fly, powerplant, hyundai, alus, bartlett, astrolabe,
# Nearest to joseph: sunga, wealthy, resurface, giancana, edmond, kampf, domestication, mandel,
# Nearest to universe: cosmology, cosmological, merril, equated, quantum, galaxies, intruders, restores,
# Nearest to units: mw, foreign, blimp, acorn, waas, csrt, makeup, excellent,
# Nearest to consists: tortoiseshell, coronal, is, colorado, legislature, maille, banias, matrices,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7524 0.0299 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8434 0.0297 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7917 0.0298 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7941 0.0298 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8427 0.0293 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.9042 0.0306 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8300 0.0306 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8541 0.0300 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8920 0.0303 sec/batch
# Nearest to from: the, is, of, in, and, after, one, that,
# Nearest to eight: seven, six, nine, two, one, five, four, three,
# Nearest to at: in, zero, highbury, during, the, after, of, and,
# Nearest to use: used, such, eighties, yehovah, worsening, disabled, decrypt, oicw,
# Nearest to had: was, he, later, were, before, already, overshadowing, became,
# Nearest to such: as, also, many, chelating, the, and, popular, taiwanese,
# Nearest to that: the, it, from, not, all, of, is, has,
# Nearest to if: removing, will, subexpression, relapses, blocked, prepared, such, hco,
# Nearest to engine: engines, centrifugal, powerplant, fly, hyundai, airframe, balmoral, lner,
# Nearest to joseph: smith, cavalier, resurface, hemispheric, abingdon, checkpoint, olds, manor,
# Nearest to universe: cosmology, cosmological, dark, restores, baron, merril, movies, series,
# Nearest to units: unit, makeup, gibbon, csrt, mw, kj, downrock, pb,
# Nearest to consists: is, tortoiseshell, algol, shuffle, maille, consist, commissions, presides,
# Nearest to brother: younger, phoenix, flavia, washed, stunningly, paphos, osa, ee,
# Nearest to hit: charts, rankings, hits, epitomised, diana, voortrekkers, rhead, tactical,
# Nearest to instance: saving, paws, blondie, horns, return, anac, weighting, confidences,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8250 0.0310 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8402 0.0309 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8713 0.0300 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8733 0.0294 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8821 0.0293 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8528 0.0295 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8683 0.0294 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8524 0.0295 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8878 0.0298 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8264 0.0296 sec/batch
# Nearest to from: the, is, of, in, and, that, one, which,
# Nearest to eight: seven, six, nine, one, two, four, five, three,
# Nearest to at: in, zero, after, the, during, highbury, near, of,
# Nearest to use: such, yehovah, used, worsening, eighties, fluent, disabled, lightfoot,
# Nearest to had: was, he, later, before, overshadowing, were, already, have,
# Nearest to such: as, also, many, chelating, and, use, popular, the,
# Nearest to that: the, it, from, not, is, all, of, for,
# Nearest to if: will, removing, subexpression, relapses, blocked, sends, prepared, bongos,
# Nearest to engine: engines, centrifugal, fly, powerplant, airframe, hyundai, balmoral, ocho,
# Nearest to joseph: smith, cavalier, hemispheric, resurface, abingdon, giancana, checkpoint, greenwich,
# Nearest to universe: cosmology, cosmological, restores, dark, baron, merril, posits, baudrillard,
# Nearest to units: unit, gibbon, makeup, csrt, mw, kj, downrock, pb,
# Nearest to consists: tortoiseshell, algol, is, shuffle, presides, maille, consist, commissions,
# Nearest to brother: younger, washed, flavia, phoenix, stunningly, ravaged, cimmeria, osa,
# Nearest to hit: rankings, charts, hits, epitomised, voortrekkers, diana, rhead, tactical,
# Nearest to instance: saving, blondie, paws, horns, anac, fined, return, seigneurial,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8797 0.0309 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8578 0.0296 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8191 0.0295 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8464 0.0297 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9174 0.0292 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8422 0.0304 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9588 0.0298 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9148 0.0298 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9064 0.0294 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8153 0.0301 sec/batch
# Nearest to from: the, of, and, in, is, one, after, a,
# Nearest to eight: seven, six, nine, one, two, four, five, three,
# Nearest to at: in, zero, after, during, highbury, near, from, hospital,
# Nearest to use: such, used, eighties, may, yehovah, often, worsening, as,
# Nearest to had: was, he, later, before, already, overshadowing, resisted, been,
# Nearest to such: as, also, many, use, chelating, the, other, and,
# Nearest to that: the, it, not, from, all, since, of, is,
# Nearest to if: will, removing, subexpression, relapses, bijection, be, abhorrent, such,
# Nearest to engine: engines, centrifugal, powerplant, fly, airframe, hyundai, balmoral, bartlett,
# Nearest to joseph: smith, cavalier, giancana, checkpoint, hemispheric, resurface, greenwich, worded,
# Nearest to universe: cosmology, cosmological, merril, restores, baron, dark, series, posits,
# Nearest to units: unit, gibbon, csrt, makeup, mw, samar, downrock, kj,
# Nearest to consists: tortoiseshell, is, algol, shuffle, presides, maille, consist, commissions,
# Nearest to brother: younger, washed, phoenix, flavia, stunningly, later, cimmeria, osa,
# Nearest to hit: rankings, charts, hits, epitomised, voortrekkers, diana, rhead, ewell,
# Nearest to instance: saving, paws, blondie, horns, weighting, anac, intersystems, royce,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8201 0.0309 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8621 0.0299 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7454 0.0293 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8822 0.0294 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8442 0.0301 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8201 0.0295 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9062 0.0148 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8183 0.0295 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8291 0.0296 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8268 0.0299 sec/batch
# Nearest to from: the, of, and, in, is, after, which, at,
# Nearest to eight: seven, six, one, nine, two, four, five, three,
# Nearest to at: in, the, from, after, of, near, zero, highbury,
# Nearest to use: such, used, yehovah, eighties, worsening, equivalent, today, oicw,
# Nearest to had: was, he, later, before, already, been, could, overshadowing,
# Nearest to such: as, also, chelating, many, use, related, other, popular,
# Nearest to that: the, not, it, from, of, all, never, fine,
# Nearest to if: will, removing, subexpression, relapses, blocked, bijection, abhorrent, bongos,
# Nearest to engine: engines, centrifugal, powerplant, fly, airframe, bartlett, balmoral, miata,
# Nearest to joseph: smith, cavalier, hemispheric, giancana, lessing, checkpoint, opened, gioacchino,
# Nearest to universe: cosmology, cosmological, restores, merril, posits, dark, baron, series,
# Nearest to units: unit, gibbon, makeup, csrt, mw, downrock, pb, samar,
# Nearest to consists: tortoiseshell, is, algol, shuffle, maille, presides, consist, consisting,
# Nearest to brother: younger, father, washed, flavia, phoenix, daughters, later, cerialis,
# Nearest to hit: rankings, charts, hits, epitomised, voortrekkers, diana, tactical, rhead,
# Nearest to instance: saving, paws, blondie, weighting, fined, return, horns, confidences,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8235 0.0309 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8560 0.0298 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8101 0.0299 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8090 0.0300 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8663 0.0298 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8277 0.0293 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8653 0.0294 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7449 0.0298 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8192 0.0295 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7887 0.0296 sec/batch
# Nearest to from: the, of, is, in, and, that, which, after,
# Nearest to eight: seven, six, one, two, four, nine, five, three,
# Nearest to at: in, the, highbury, after, zero, to, eight, of,
# Nearest to use: used, such, may, yehovah, equivalent, as, often, though,
# Nearest to had: was, he, later, before, were, already, could, became,
# Nearest to such: as, also, many, and, the, chelating, other, use,
# Nearest to that: the, it, not, from, of, has, is, to,
# Nearest to if: will, removing, be, subexpression, is, then, such, bijection,
# Nearest to engine: engines, centrifugal, powerplant, fly, airframe, balmoral, lner, hyundai,
# Nearest to joseph: smith, hemispheric, cavalier, abingdon, resurface, giancana, checkpoint, greenwich,
# Nearest to universe: cosmology, cosmological, merril, dark, posits, restores, baron, fan,
# Nearest to units: unit, gibbon, csrt, makeup, mw, samar, pb, downrock,
# Nearest to consists: is, tortoiseshell, algol, shuffle, maille, consist, the, okresy,
# Nearest to brother: younger, washed, phoenix, osa, ee, flavia, stunningly, cimmeria,
# Nearest to hit: rankings, hits, charts, voortrekkers, epitomised, ewell, hitters, tactical,
# Nearest to instance: saving, paws, return, weighting, horns, seigneurial, blondie, oxley,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7395 0.0311 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7952 0.0291 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8600 0.0296 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8331 0.0299 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8312 0.0302 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9008 0.0303 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8393 0.0300 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8233 0.0299 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8314 0.0302 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8480 0.0298 sec/batch
# Nearest to from: the, in, of, is, and, after, that, a,
# Nearest to eight: seven, six, one, two, nine, four, five, three,
# Nearest to at: in, after, the, eight, zero, during, from, highbury,
# Nearest to use: used, such, yehovah, equivalent, decrypt, eighties, may, though,
# Nearest to had: was, he, later, before, did, were, already, been,
# Nearest to such: as, also, and, many, popular, the, use, other,
# Nearest to that: the, it, not, from, has, of, is, most,
# Nearest to if: will, removing, blocked, subexpression, then, bijection, bongos, relapses,
# Nearest to engine: engines, centrifugal, powerplant, airframe, fly, bartlett, balmoral, miata,
# Nearest to joseph: smith, cavalier, giancana, hemispheric, abingdon, resurface, checkpoint, opened,
# Nearest to universe: cosmology, cosmological, dark, merril, baron, posits, baudrillard, restores,
# Nearest to units: unit, gibbon, makeup, csrt, mw, pb, downrock, samar,
# Nearest to consists: is, tortoiseshell, shuffle, algol, maille, presides, consist, unicameral,
# Nearest to brother: younger, washed, flavia, cimmeria, phoenix, father, paphos, daughters,
# Nearest to hit: hits, rankings, charts, voortrekkers, epitomised, ewell, diana, rhead,
# Nearest to instance: saving, paws, return, anac, fined, horns, blondie, tms,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8933 0.0307 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8340 0.0297 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8134 0.0304 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8599 0.0300 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8795 0.0302 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8308 0.0302 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8377 0.0296 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8666 0.0298 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8176 0.0299 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8057 0.0299 sec/batch
# Nearest to from: the, is, in, and, of, that, one, which,
# Nearest to eight: seven, six, two, four, one, five, nine, three,
# Nearest to at: in, zero, eight, the, after, near, from, up,
# Nearest to use: such, used, often, equivalent, yehovah, may, though, decrypt,
# Nearest to had: was, later, he, before, became, been, were, until,
# Nearest to such: as, also, and, many, the, other, use, in,
# Nearest to that: the, it, not, from, has, of, be, is,
# Nearest to if: will, removing, be, such, bongos, relapses, then, so,
# Nearest to engine: engines, centrifugal, powerplant, airframe, bartlett, fly, balmoral, lner,
# Nearest to joseph: smith, cavalier, checkpoint, giancana, resurface, hemispheric, abingdon, opened,
# Nearest to universe: cosmology, cosmological, dark, merril, baron, posits, restores, baudrillard,
# Nearest to units: unit, gibbon, csrt, makeup, mw, samar, pb, waas,
# Nearest to consists: is, tortoiseshell, algol, shuffle, okresy, consist, the, presides,
# Nearest to brother: younger, washed, phoenix, cimmeria, father, osa, flavia, paphos,
# Nearest to hit: rankings, hits, voortrekkers, charts, epitomised, ewell, diana, tong,
# Nearest to instance: saving, paws, return, anac, seigneurial, fined, tms, horns,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8816 0.0310 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8129 0.0302 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9137 0.0301 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9140 0.0301 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8784 0.0293 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8486 0.0300 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7831 0.0297 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8268 0.0300 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7007 0.0297 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8748 0.0298 sec/batch
# Nearest to from: the, and, of, is, in, which, a, that,
# Nearest to eight: seven, six, one, nine, four, two, five, three,
# Nearest to at: in, zero, eight, after, during, near, the, hospital,
# Nearest to use: such, used, often, decrypt, yehovah, equivalent, lightfoot, as,
# Nearest to had: was, he, later, before, been, became, overshadowing, have,
# Nearest to such: as, also, and, many, chelating, use, other, related,
# Nearest to that: the, it, not, from, has, is, be, what,
# Nearest to if: will, removing, so, then, be, subexpression, bijection, say,
# Nearest to engine: engines, centrifugal, powerplant, airframe, fly, bartlett, balmoral, superchargers,
# Nearest to joseph: smith, cavalier, hemispheric, checkpoint, giancana, gioacchino, opened, abingdon,
# Nearest to universe: cosmology, cosmological, merril, posits, baron, fan, dark, restores,
# Nearest to units: unit, gibbon, csrt, mw, makeup, samar, pb, suggests,
# Nearest to consists: is, tortoiseshell, algol, each, shuffle, consist, the, presides,
# Nearest to brother: younger, washed, phoenix, cimmeria, osa, father, stunningly, paphos,
# Nearest to hit: rankings, charts, hits, voortrekkers, epitomised, diana, ewell, chart,
# Nearest to instance: saving, paws, are, fined, anac, blondie, return, tms,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8193 0.0312 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8201 0.0296 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
